# %% [markdown]
# ## Logistic Regression
# la funcion del workshop 6,3.- es lineal
# Que se puede hacer:
# Encontrar los w's que mejoran nuestra separacion de datos (como?) no importa
# sklearn lo hace solo
# esto predice las clases, se quita una para que no sea tan complicado y se corre LogisticRegression()
# En multiclase se vuelve más complicado. Se utilizan tecnicas mas burdas, se crean multiples clasificadores para reducir las clases.

# %%
from sklearn import linear_model
logreg = linear_model.LogisticRegression()
dfNew = dfIris[dfIris['species']!='setosa']
X=dfNew[['sepal_length','sepal_width','petal_length','petal_width']]
y=dfNew[['species']]
logreg.fit(X,y)
y_pred = logreg.predict(X)

# %% [markdown]
# Lo hace bien para las versicolor pero para las virginicas se equivocó, por eso se trata
# de minimizar con el testing, entrenando con el testing

# %%
import pandas as pd
import numpy as np
Data=pd.read_csv('optical_interconnection_network.csv')
Data
# Out:
#                                                                                       Node Number;Thread Number;Spatial Distribution;Temporal Distribution;T/R;Processor Utilization ;Channel Waiting Time;Input Waiting Time;Network Response Time;Channel Utilization;;;;;
# 64;4;UN;Client-Server;0   1;0         839546;1    974686;308  491814;700  514102;0                                           352431;;;;;
#                           2;0         827412;9    556437;291  037663;864  599227;0                                           506302;;;;;
#                           3;0         802605;27   027618;264  928002;839  372851;0                                           638516;;;;;
#                           4;0         723403;61   848511;235  776888;1256 053108;0                                           767051;;;;;
#                           5;0         72121;121   085884;189  680044;1343 875577;0                                           807812;;;;;
# ...

# %%
from sklearn import linear_model
logreg = linear_model.LogisticRegression()
dfNew = dfDrugs[dfDrugs['species']!='setosa']
X=dfNew[['effectivenesss','sepal_width','petal_length','petal_width']]
y=dfNew[['species']]
logreg.fit(X,y)
y_pred = logreg.predict(X)
